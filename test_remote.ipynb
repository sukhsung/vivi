# %%
from serial.tools.list_ports import comports as list_ports
from serial import Serial

# %%
print( [p.device for p in list_ports() if p.vid] )
# Out:
# <function comports at 0x10662cdc0>
